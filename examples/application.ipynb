# %%
import numpy as np
from numpy.typing import NDArray
import matplotlib.pyplot as plt

from pyspectrum import Spectrometer, Spectrum
s = Spectrum.load('lamp2')
from LEDCalculator import LedParameters

# %%
led= LedParameters()

# %%
led.run(s)
# Out:
# (2446.3090654243874,
#  1.0500255990090268,
#  {'1': 84.57428148771315,
#   '2': 87.718152019661,
#   '3': 89.1980986837412,
#   '4': 86.19462667359038,
#   '5': 86.76599474052648,
#   '6': 87.35206629980102,
#   '7': 86.77717600694268,
#   '8': 83.15537885004375,
#   '9': 60.91426306292729,
#   '10': 86.88791934043866,
#   '11': 82.73039976366385,
#   '12': 77.5423822855465,
#   '13': 86.4430698234118,
#   '14': 89.18741513283356,
#   'cri': 83.96008744077439})

# %%
led.show()
